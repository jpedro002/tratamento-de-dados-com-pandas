# %%
import pandas as pd

minhaTabela = pd.read_excel('respostas-form.xlsx')

display(minhaTabela)
# Out:
#       Carimbo de data/hora                     Qual é a sua área? Seu turno:  \
# 0  2023-11-01 20:55:09.166                 Ciência da computação    Matutino
# 1  2023-11-01 20:59:41.886               Tecnologia da Informação    Noturno
# 2  2023-11-01 21:00:43.547                         Administração     Noturno
# 3  2023-11-01 21:01:18.264                      Ciências da Saúde   Matutino
# 4  2023-11-01 21:05:03.840               Tecnologia da Informação    Noturno
# 5  2023-11-01 21:15:27.582               Tecnologia da Informação    Noturno
# 6  2023-11-01 21:16:46.977                              nutrição    Matutino
# 7  2023-11-01 21:17:59.869                      Ciências da Saúde   Matutino
# 8  2023-11-01 21:19:52.269               Tecnologia da Informação    Noturno
# 9  2023-11-01 21:19:53.938               Tecnologia da Informação   Matutino
# 10 2023-11-01 21:21:13.616                      Ciências da Saúde   Matutino
# ...

# %%
mapeamento = {
    'Menos de 30 Minutos': 0,
    'Menos de 1 Hora': 0,
    '1 Hora': 1,
    '2 Horas': 2,
    '3 Horas': 3,
    '4 Horas': 4,
    '5 Horas': 5,
}

minhaTabela['Aproximadamente quanto tempo você dedica aos estudos por dia?'] = minhaTabela['Aproximadamente quanto tempo você dedica aos estudos por dia?'].replace(mapeamento)

# %%
display(minhaTabela['Aproximadamente quanto tempo você dedica aos estudos por dia?'])
# Out:
# 0                       4
# 1     Menos de 30 Minutos
# 2                       2
# 3                       2
# 4                       1
# 5                       1
# 6                       2
# 7                       2
# 8     Menos de 30 Minutos
# 9                       2
# 10                      1
# 11                      4
# 12                      1
# 13                      1
# 14                      2
# 15                      1
# 16                      1
# 17                      2
# 18                      4
# 19                      4
# 20                      3
# 21                      2
# 22    Menos de 30 Minutos
# 23                      3
# 24    Menos de 30 Minutos
# 25                      1
# 26    Menos de 30 Minutos
# 27                      1
# 28                      2
# 29                      1
# 30                      4
# 31                      3
# 32                      2
# 33                      1
# 34                      2
# ...
